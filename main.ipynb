# %%
from utils import DryingModel

# %%
M_0 = 0.1
M_eq = 0.02
N_x = 50  
L = 0.01
D = 1.0e-9
h = 0.005
N_t = 2000

model = DryingModel(M_0 = M_0, 
                    M_eq = M_eq, 
                    N_x = N_x, 
                    L = L, 
                    D = D, 
                    h = h, 
                    N_t = N_t
                    )

# %%
cuts_location = [0, 0.5, 0.9, 1.0]  # as fraction of L

model.simulate_diffusion()
model.plot_cuts(cuts_location)
# Out:
# c:\Users\bruno\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_index.py:108: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# (2001, 50)
# [0.1  0.1  0.1  ... 0.02 0.02 0.02]
# (2001, 50)
# [0.1        0.09999878 0.09998545 ... 0.02       0.02       0.02      ]
# (2001, 50)
# [0.1        0.0912961  0.07229938 ... 0.02       0.02       0.02      ]
# (2001, 50)
# [0.1       0.0200331 0.0200033 ... 0.02      0.02      0.02     ]

# %%
model.validate_model()
# Out:
# === RESULTADOS DE LA VALIDACIÓN (ARRANZA) ===
# Pendiente (b): -0.000025
# Intercepto (a): -0.205005
# R-cuadrado: 1.000000
